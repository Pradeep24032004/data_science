# %% [markdown]
# <a href="https://colab.research.google.com/github/Pradeep24032004/data_science/blob/main/PandasBasics.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
#pandas
#pandas generally mean(python data analysis library)
#This library is built on top of the Numpy library of python. Pandas is fast and it has high performance abd productivity of users.
#(1). Pandas is fast and efficient for manipulating and analyzing data
#(2). Data from different file objects can be easily loaded
#(3). Flexible reshaping and pivoting of data sets
#(4).Provides time-series functionality
'''
* Pandas are generally used for data science but have you wondered why?
* This is because pandas are used in conjunction with other librarires that are used for data science.
* This is built on the top of the NumPy library which means that a lot of structures of NumPy are used or replicated in Pandas.
* The data produced by Pandas are often used as input for plotting functions of Matplotlib, statistical analysis in Scipy,
and machine learning algorithms in Scikit-learn.
'''
# Out:
# '\n* Pandas are generally used for data science but have you wondered why?\n* This is because pandas are used in conjunction with other librarires that are used for data science.\n* This is built on the top of the NumPy library which means that a lot of structures of NumPy are used or replicated in Pandas.\n* The data produced by Pandas are often used as input for plotting functions of Matplotlib, statistical analysis in Scipy,\nand machine learning algorithms in Scikit-learn.\n'

# %%
#syntax for pandas
import pandas as pd
'''
Pandas Data Structures
Pandas generally provide two data structures for manipulating data, They are:
(1)Series - columns
(2)Data Frames - (columns + rows)
'''
# Out:
# '\nPandas Data Structures\nPandas generally provide two data structures for manipulating data, They are:\n(1)Series - columns\n(2)Data Frames - (columns + rows)\n'

# %%
'''
* Pandas series is a one-dimensiona; labeled array capable of holding data of any type (integer, string, float, python objects, etc.).
The axis labels are collectively called indexes.
* Pandas series is nothing but a column in an Excel sheet.
'''
import pandas as pd
ser = pd.Series(dtype = object)
ser
# Out:
# Series([], dtype: object)

# %%
#creating a series from a List
import pandas as pd
data = [1,2,3,4,5]
series_from_list = pd.Series(data)
print("series from list",series_from_list)

#creating a series with custom index using dictionary
data1 = {'a':1, 'b':2, 'c':3, 'd':4, 'e':5}
series_from_dict = pd.Series(data1)
print("series from dictionary",series_from_dict)
# Out:
# series from list 0    1
# 1    2
# 2    3
# 3    4
# 4    5
# dtype: int64
# series from dictionary a    1
# b    2
# c    3
# d    4
# e    5
# dtype: int64

# %%
#Data Frame
'''
In the real world, a pandas DataFrame will be created by loading the datasets from existing storage, storage can be SQL Database,
csv file, or an Exel File. Pandas DatFrame can be created from lists, dictionaries, and from a list of dictionaries, etc.
'''
import pandas as pd
df = pd.DataFrame()
df
# Out:
# Empty DataFrame
# Columns: []
# Index: []

# %%
#Example 1 : Creating a data frame using lists
data = [
    ['Alice',25,'New York'],
    ['Bob',30,'San Francisco'],
    ['Charlie',35,'Los Angels']
]
#custom column creation
custom_columns = ['Name','Age','City']
df = pd.DataFrame(data,columns=custom_columns)
print(df)
# Out:
#       Name  Age           City
# 0    Alice   25       New York
# 1      Bob   30  San Francisco
# 2  Charlie   35     Los Angels

# %%
#Example 2 : creating a data frame using dictionary
data1 = {
    'Name':['Alice','Bob','Charlie'],
    'Age':[25,30,35],
    'City':['New York','San Francisco','Los Angeles']
}
df = pd.DataFrame(data1)
print(df)
# Out:
#       Name  Age           City
# 0    Alice   25       New York
# 1      Bob   30  San Francisco
# 2  Charlie   35    Los Angeles

# %%
#Example 3: creating a data frame from series(home work)

# %%
'''
Analyzing a DataFrame

Create a dataframe with information about sales data for a small store.
The DataFrame should include columns for "Product Name", "Price" and "Quality Sold".
Then, calculate the total revenue for each product(price * Quantity Sold) and display the DataFrame with the total revenue column added.
'''
# Out:
# '\nAnalyzing a DataFrame\n\nCreate a dataframe with information about sales data for a small store.\nThe DataFrame should include columns for "Product Name", "Price" and "Quality Sold".\nThen, calculate the total revenue for each product(price * Quantity Sold) and display the DataFrame with the total revenue column added.\n'

# %%
import pandas as pd
data = {
    'Product Name':['Product A','Product B','Product C','Product D'],
    'Price':[10.99,5.99,8.49,12.49],
    'Quantity Sold':[100,150,80,200]
}
#step 1: converting dictionary into a dataframe
sales_df = pd.DataFrame(data)
print(sales_df)
print('\n')
#step 2: calculating the total revenue
sales_df['total revenue'] = sales_df['Price']*sales_df['Quantity Sold']
print(sales_df)
sales_df['Discount'] = sales_df['Price']*0.1
print('\n')
print(sales_df)
print('\n')
sales_df['Revised_product_price_after_discount']=sales_df['Price'] - sales_df['Discount']
print(sales_df)
# Out:
#   Product Name  Price  Quantity Sold
# 0    Product A  10.99            100
# 1    Product B   5.99            150
# 2    Product C   8.49             80
# 3    Product D  12.49            200
#
#
#   Product Name  Price  Quantity Sold  total revenue
# 0    Product A  10.99            100         1099.0
# 1    Product B   5.99            150          898.5
# 2    Product C   8.49             80          679.2
# 3    Product D  12.49            200         2498.0
#
#
#   Product Name  Price  Quantity Sold  total revenue  Discount
# 0    Product A  10.99            100         1099.0     1.099
# 1    Product B   5.99            150          898.5     0.599
# 2    Product C   8.49             80          679.2     0.849
# 3    Product D  12.49            200         2498.0     1.249
#
#
#   Product Name  Price  Quantity Sold  total revenue  Discount  \
# 0    Product A  10.99            100         1099.0     1.099
# 1    Product B   5.99            150          898.5     0.599
# ...

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).

# %%
# %cd /content/drive/My Drive/datascience
# %pwd
# %ls
# Out:
# /content/drive/My Drive/datascience
# nba.csv  titanic.csv

# %%
#reading the csv file
import pandas as pd
df = pd.read_csv('titanic.csv')
df
# Out:
#      PassengerId  Survived  Pclass  \
# 0              1         0       3
# 1              2         1       1
# 2              3         1       3
# 3              4         1       1
# 4              5         0       3
# ..           ...       ...     ...
# 886          887         0       2
# 887          888         1       1
# 888          889         0       3
# 889          890         1       1
# 890          891         0       3
#
#                                                   Name     Sex   Age  SibSp  \
# 0                              Braund, Mr. Owen Harris    male  22.0      1
# 1    Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                               Heikkinen, Miss. Laina  female  26.0      0
# 3         Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 4                             Allen, Mr. William Henry    male  35.0      0
# ..                                                 ...     ...   ...    ...
# ...

# %%
#overall information of the dataset
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 891 entries, 0 to 890
# Data columns (total 12 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   PassengerId  891 non-null    int64
#  1   Survived     891 non-null    int64
#  2   Pclass       891 non-null    int64
#  3   Name         891 non-null    object
#  4   Sex          891 non-null    object
#  5   Age          714 non-null    float64
#  6   SibSp        891 non-null    int64
#  7   Parch        891 non-null    int64
#  8   Ticket       891 non-null    object
#  9   Fare         891 non-null    float64
#  10  Cabin        204 non-null    object
#  11  Embarked     889 non-null    object
# dtypes: float64(2), int64(5), object(5)
# memory usage: 83.7+ KB

# %%
#finding the shape of the dataset
df.shape
# Out:
# (891, 12)

# %%
#finding the size of the dataset
df.size #equivalent to no of rows and no of columns
# Out:
# 10692

# %%
#dimensionality of the dataset
df.ndim
# Out:
# 2

# %%
#printing head and tail of the dataset
df.head(10) #gives first 10 rows
# Out:
#    PassengerId  Survived  Pclass  \
# 0            1         0       3
# 1            2         1       1
# 2            3         1       3
# 3            4         1       1
# 4            5         0       3
# 5            6         0       3
# 6            7         0       1
# 7            8         0       3
# 8            9         1       3
# 9           10         1       2
#
#                                                 Name     Sex   Age  SibSp  \
# 0                            Braund, Mr. Owen Harris    male  22.0      1
# 1  Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                             Heikkinen, Miss. Laina  female  26.0      0
# 3       Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 4                           Allen, Mr. William Henry    male  35.0      0
# 5                                   Moran, Mr. James    male   NaN      0
# ...

# %%
#tail function
df.tail(10) #prints last 10 rows
# Out:
#      PassengerId  Survived  Pclass                                      Name  \
# 881          882         0       3                        Markun, Mr. Johann
# 882          883         0       3              Dahlberg, Miss. Gerda Ulrika
# 883          884         0       2             Banfield, Mr. Frederick James
# 884          885         0       3                    Sutehall, Mr. Henry Jr
# 885          886         0       3      Rice, Mrs. William (Margaret Norton)
# 886          887         0       2                     Montvila, Rev. Juozas
# 887          888         1       1              Graham, Miss. Margaret Edith
# 888          889         0       3  Johnston, Miss. Catherine Helen "Carrie"
# 889          890         1       1                     Behr, Mr. Karl Howell
# 890          891         0       3                       Dooley, Mr. Patrick
#
#         Sex   Age  SibSp  Parch            Ticket     Fare Cabin Embarked
# ...

# %%
#accessing all rows except last 1o0 rows
df.head(-10)
# Out:
#      PassengerId  Survived  Pclass  \
# 0              1         0       3
# 1              2         1       1
# 2              3         1       3
# 3              4         1       1
# 4              5         0       3
# ..           ...       ...     ...
# 876          877         0       3
# 877          878         0       3
# 878          879         0       3
# 879          880         1       1
# 880          881         1       2
#
#                                                   Name     Sex   Age  SibSp  \
# 0                              Braund, Mr. Owen Harris    male  22.0      1
# 1    Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                               Heikkinen, Miss. Laina  female  26.0      0
# 3         Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 4                             Allen, Mr. William Henry    male  35.0      0
# ..                                                 ...     ...   ...    ...
# ...

# %%
#accessing all rows except first 10 rows
df.tail(-10)
# Out:
#      PassengerId  Survived  Pclass                                      Name  \
# 10            11         1       3           Sandstrom, Miss. Marguerite Rut
# 11            12         1       1                  Bonnell, Miss. Elizabeth
# 12            13         0       3            Saundercock, Mr. William Henry
# 13            14         0       3               Andersson, Mr. Anders Johan
# 14            15         0       3      Vestrom, Miss. Hulda Amanda Adolfina
# ..           ...       ...     ...                                       ...
# 886          887         0       2                     Montvila, Rev. Juozas
# 887          888         1       1              Graham, Miss. Margaret Edith
# 888          889         0       3  Johnston, Miss. Catherine Helen "Carrie"
# 889          890         1       1                     Behr, Mr. Karl Howell
# 890          891         0       3                       Dooley, Mr. Patrick
#
# ...

# %%
#select all rows excluding bottom 157 rows using head() function. what is the fare in the last row?
df.head(-157)
# Out:
#      PassengerId  Survived  Pclass  \
# 0              1         0       3
# 1              2         1       1
# 2              3         1       3
# 3              4         1       1
# 4              5         0       3
# ..           ...       ...     ...
# 729          730         0       3
# 730          731         1       1
# 731          732         0       3
# 732          733         0       2
# 733          734         0       2
#
#                                                   Name     Sex   Age  SibSp  \
# 0                              Braund, Mr. Owen Harris    male  22.0      1
# 1    Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                               Heikkinen, Miss. Laina  female  26.0      0
# 3         Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 4                             Allen, Mr. William Henry    male  35.0      0
# ..                                                 ...     ...   ...    ...
# ...

# %%
#select all rows excluding top 17 rows using tail() function. what is the fare in the first row
df.tail(-17)
# Out:
#      PassengerId  Survived  Pclass  \
# 17            18         1       2
# 18            19         0       3
# 19            20         1       3
# 20            21         0       2
# 21            22         1       2
# ..           ...       ...     ...
# 886          887         0       2
# 887          888         1       1
# 888          889         0       3
# 889          890         1       1
# 890          891         0       3
#
#                                                   Name     Sex   Age  SibSp  \
# 17                        Williams, Mr. Charles Eugene    male   NaN      0
# 18   Vander Planke, Mrs. Julius (Emelia Maria Vande...  female  31.0      1
# 19                             Masselmani, Mrs. Fatima  female   NaN      0
# 20                                Fynney, Mr. Joseph J    male  35.0      0
# 21                               Beesley, Mr. Lawrence    male  34.0      0
# ..                                                 ...     ...   ...    ...
# ...

# %%
#describing the dataset
df.describe()
# Out:
#        PassengerId    Survived      Pclass         Age       SibSp  \
# count   891.000000  891.000000  891.000000  714.000000  891.000000
# mean    446.000000    0.383838    2.308642   29.699118    0.523008
# std     257.353842    0.486592    0.836071   14.526497    1.102743
# min       1.000000    0.000000    1.000000    0.420000    0.000000
# 25%     223.500000    0.000000    2.000000   20.125000    0.000000
# 50%     446.000000    0.000000    3.000000   28.000000    0.000000
# 75%     668.500000    1.000000    3.000000   38.000000    1.000000
# max     891.000000    1.000000    3.000000   80.000000    8.000000
#
#             Parch        Fare
# count  891.000000  891.000000
# mean     0.381594   32.204208
# std      0.806057   49.693429
# min      0.000000    0.000000
# 25%      0.000000    7.910400
# 50%      0.000000   14.454200
# 75%      0.000000   31.000000
# max      6.000000  512.329200

# %%
#accessing the columns of the dataset
print(df['Name'])
print('\n')
print(df['Age'])
# Out:
# 0                                Braund, Mr. Owen Harris
# 1      Cumings, Mrs. John Bradley (Florence Briggs Th...
# 2                                 Heikkinen, Miss. Laina
# 3           Futrelle, Mrs. Jacques Heath (Lily May Peel)
# 4                               Allen, Mr. William Henry
#                              ...
# 886                                Montvila, Rev. Juozas
# 887                         Graham, Miss. Margaret Edith
# 888             Johnston, Miss. Catherine Helen "Carrie"
# 889                                Behr, Mr. Karl Howell
# 890                                  Dooley, Mr. Patrick
# Name: Name, Length: 891, dtype: object
#
#
# 0      22.0
# 1      38.0
# 2      26.0
# 3      35.0
# 4      35.0
#        ...
# 886    27.0
# 887    19.0
# 888     NaN
# 889    26.0
# 890    32.0
# Name: Age, Length: 891, dtype: float64

# %%
#accessing multiple columns
df[['Name','Age']] #make a list of columns which are need to be accessed and pass it to df
# Out:
#                                                   Name   Age
# 0                              Braund, Mr. Owen Harris  22.0
# 1    Cumings, Mrs. John Bradley (Florence Briggs Th...  38.0
# 2                               Heikkinen, Miss. Laina  26.0
# 3         Futrelle, Mrs. Jacques Heath (Lily May Peel)  35.0
# 4                             Allen, Mr. William Henry  35.0
# ..                                                 ...   ...
# 886                              Montvila, Rev. Juozas  27.0
# 887                       Graham, Miss. Margaret Edith  19.0
# 888           Johnston, Miss. Catherine Helen "Carrie"   NaN
# 889                              Behr, Mr. Karl Howell  26.0
# 890                                Dooley, Mr. Patrick  32.0
#
# [891 rows x 2 columns]

# %%
#exploring max, min and mean function
print("max value of fare",df['Fare'].max())
print("min value of fare",df['Fare'].min())
print("mean value of the fare",df['Fare'].mean())
print("sum of values of fare",df['Fare'].sum())
# Out:
# max value of fare 512.3292
# min value of fare 0.0
# mean value of the fare 32.204207968574636
# sum of values of fare 28693.9493

# %%
#finding missing values of the dataset
print(df.isna()) #is null operation
print('\n')
print("no of null values in each column ",df.isna().sum())
# Out:
#      PassengerId  Survived  Pclass   Name    Sex    Age  SibSp  Parch  Ticket  \
# 0          False     False   False  False  False  False  False  False   False
# 1          False     False   False  False  False  False  False  False   False
# 2          False     False   False  False  False  False  False  False   False
# 3          False     False   False  False  False  False  False  False   False
# 4          False     False   False  False  False  False  False  False   False
# ..           ...       ...     ...    ...    ...    ...    ...    ...     ...
# 886        False     False   False  False  False  False  False  False   False
# 887        False     False   False  False  False  False  False  False   False
# 888        False     False   False  False  False   True  False  False   False
# 889        False     False   False  False  False  False  False  False   False
# 890        False     False   False  False  False  False  False  False   False
#
#       Fare  Cabin  Embarked
# ...

# %%
#dropping the missing values from the dataset
print(df.dropna()) #dropping all the null values
print('\n')
#dropna using how parameter
print("using how=any \n",df.dropna(how='any')) #if any column in aparticular row is null then it drops the entire row
print("using how=all \n",df.dropna(how='all')) #drops all null valued columns
# Out:
#      PassengerId  Survived  Pclass  \
# 1              2         1       1
# 3              4         1       1
# 6              7         0       1
# 10            11         1       3
# 11            12         1       1
# ..           ...       ...     ...
# 871          872         1       1
# 872          873         0       1
# 879          880         1       1
# 887          888         1       1
# 889          890         1       1
#
#                                                   Name     Sex   Age  SibSp  \
# 1    Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 3         Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 6                              McCarthy, Mr. Timothy J    male  54.0      0
# 10                     Sandstrom, Miss. Marguerite Rut  female   4.0      1
# 11                            Bonnell, Miss. Elizabeth  female  58.0      0
# ..                                                 ...     ...   ...    ...
# ...

# %%
#to permunantly manupilate the dataset
df.dropna(how='all',inplace=True) #makes permenant changes, drops all the null values
print(df)
# Out:
#      PassengerId  Survived  Pclass  \
# 0              1         0       3
# 1              2         1       1
# 2              3         1       3
# 3              4         1       1
# 4              5         0       3
# ..           ...       ...     ...
# 886          887         0       2
# 887          888         1       1
# 888          889         0       3
# 889          890         1       1
# 890          891         0       3
#
#                                                   Name     Sex   Age  SibSp  \
# 0                              Braund, Mr. Owen Harris    male  22.0      1
# 1    Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                               Heikkinen, Miss. Laina  female  26.0      0
# 3         Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 4                             Allen, Mr. William Henry    male  35.0      0
# ..                                                 ...     ...   ...    ...
# ...

# %%
#find average age
df['Age'].mean()
# Out:
# 29.69911764705882

# %%
#dropping a particular row syntax: df.drop(index)
print("dropping 2nd row",df.drop(2))
print("\n")
#dropping multiple rows at a time by keeping them in an array
print("dropping 2nd and 3rd row", df.drop([2,3]))
# Out:
# dropping 2nd row      PassengerId  Survived  Pclass  \
# 0              1         0       3
# 1              2         1       1
# 3              4         1       1
# 4              5         0       3
# 5              6         0       3
# ..           ...       ...     ...
# 886          887         0       2
# 887          888         1       1
# 888          889         0       3
# 889          890         1       1
# 890          891         0       3
#
#                                                   Name     Sex   Age  SibSp  \
# 0                              Braund, Mr. Owen Harris    male  22.0      1
# 1    Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 3         Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 4                             Allen, Mr. William Henry    male  35.0      0
# 5                                     Moran, Mr. James    male   NaN      0
# ...

# %%
#removing a column syntax: df.drop(column_name)
df.drop('Sibsp', axis=1, inplace=True)  #changing axis to column for row axis=0 and for column axis=1
#inplace=true removes column permenantly from the dataset
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# <ipython-input-93-5701f250357a> in <cell line: 2>()
#       1 #removing a column syntax: df.drop(column_name)
# ----> 2 df.drop('Sibsp', axis=1, inplace=True)  #changing axis to column for row axis=0 and for column axis=1
#       3 #inplace=true removes column permenantly from the dataset
#
# /usr/local/lib/python3.10/dist-packages/pandas/core/frame.py in drop(self, labels, axis, index, columns, level, inplace, errors)
#    5256                 weight  1.0     0.8
#    5257         """
# -> 5258         return super().drop(
#    5259             labels=labels,
#    5260             axis=axis,
#
# /usr/local/lib/python3.10/dist-packages/pandas/core/generic.py in drop(self, labels, axis, index, columns, level, inplace, errors)
#    4547         for axis, labels in axes.items():
#    4548             if labels is not None:
# ...

# %%
#renaming the columns of the datset
df.rename(columns={'Pclass':'class'},inplace=True)
#by using inplace we change the name of column permenantly
df
# Out:
#      PassengerId  Survived  class  \
# 0              1         0      3
# 1              2         1      1
# 2              3         1      3
# 3              4         1      1
# 4              5         0      3
# ..           ...       ...    ...
# 886          887         0      2
# 887          888         1      1
# 888          889         0      3
# 889          890         1      1
# 890          891         0      3
#
#                                                   Name     Sex   Age  SibSp  \
# 0                              Braund, Mr. Owen Harris    male  22.0      1
# 1    Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                               Heikkinen, Miss. Laina  female  26.0      0
# 3         Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 4                             Allen, Mr. William Henry    male  35.0      0
# ..                                                 ...     ...   ...    ...
# ...

# %%
#unique values in a column
#step1: accessing the column
df['class'].unique()
# Out:
# array([3, 1, 2])

# %%
#accessing multiple columns
df[['class','Name','Ticket']]
# Out:
#      class                                               Name  \
# 0        3                            Braund, Mr. Owen Harris
# 1        1  Cumings, Mrs. John Bradley (Florence Briggs Th...
# 2        3                             Heikkinen, Miss. Laina
# 3        1       Futrelle, Mrs. Jacques Heath (Lily May Peel)
# 4        3                           Allen, Mr. William Henry
# ..     ...                                                ...
# 886      2                              Montvila, Rev. Juozas
# 887      1                       Graham, Miss. Margaret Edith
# 888      3           Johnston, Miss. Catherine Helen "Carrie"
# 889      1                              Behr, Mr. Karl Howell
# 890      3                                Dooley, Mr. Patrick
#
#                Ticket
# 0           A/5 21171
# 1            PC 17599
# 2    STON/O2. 3101282
# 3              113803
# 4              373450
# ..                ...
# 886            211536
# 887            112053
# ...

# %%
#count function
df['Name'].count()

# %%
#count the number of unique values in a column
print(df['class'].value_counts())
print("\n")
print(df['Sex'].value_counts())
# Out:
# class
# 3    491
# 1    216
# 2    184
# Name: count, dtype: int64
#
#
# Sex
# male      577
# female    314
# Name: count, dtype: int64

# %%
# Accessing the column directly and filtering(single condition)
#filter all data where fare value is less than 100
#Step 1: accessing the column
df['Fare']
#step 2: write the condition
df['Fare'] < 100
#step 3: accessing the filtered adata
df[df['Fare'] < 100] #nested data frame used to filter the data it is nested as one data frame is inside another data frame
# Out:
#      PassengerId  Survived  class  \
# 0              1         0      3
# 1              2         1      1
# 2              3         1      3
# 3              4         1      1
# 4              5         0      3
# ..           ...       ...    ...
# 886          887         0      2
# 887          888         1      1
# 888          889         0      3
# 889          890         1      1
# 890          891         0      3
#
#                                                   Name     Sex   Age  SibSp  \
# 0                              Braund, Mr. Owen Harris    male  22.0      1
# 1    Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                               Heikkinen, Miss. Laina  female  26.0      0
# 3         Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 4                             Allen, Mr. William Henry    male  35.0      0
# ..                                                 ...     ...   ...    ...
# ...

# %%
#filter out the data whose age is less than 18
df[df['Age'] < 18]
# Out:
#      PassengerId  Survived  class                                     Name  \
# 7              8         0      3           Palsson, Master. Gosta Leonard
# 9             10         1      2      Nasser, Mrs. Nicholas (Adele Achem)
# 10            11         1      3          Sandstrom, Miss. Marguerite Rut
# 14            15         0      3     Vestrom, Miss. Hulda Amanda Adolfina
# 16            17         0      3                     Rice, Master. Eugene
# ..           ...       ...    ...                                      ...
# 850          851         0      3  Andersson, Master. Sigvard Harald Elias
# 852          853         0      3                  Boulos, Miss. Nourelain
# 853          854         1      1                Lines, Miss. Mary Conover
# 869          870         1      3          Johnson, Master. Harold Theodor
# 875          876         1      3         Najib, Miss. Adele Kiamie "Jane"
#
#         Sex   Age  SibSp  Parch    Ticket     Fare Cabin Embarked
# ...

# %%
#filter all the data where survived is 1
df[df['Survived'] == 1]
# Out:
#      PassengerId  Survived  class  \
# 1              2         1      1
# 2              3         1      3
# 3              4         1      1
# 8              9         1      3
# 9             10         1      2
# ..           ...       ...    ...
# 875          876         1      3
# 879          880         1      1
# 880          881         1      2
# 887          888         1      1
# 889          890         1      1
#
#                                                   Name     Sex   Age  SibSp  \
# 1    Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                               Heikkinen, Miss. Laina  female  26.0      0
# 3         Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 8    Johnson, Mrs. Oscar W (Elisabeth Vilhelmina Berg)  female  27.0      0
# 9                  Nasser, Mrs. Nicholas (Adele Achem)  female  14.0      1
# ..                                                 ...     ...   ...    ...
# ...

# %%
#filter all the data whose sex is male
df[df['Sex'] == 'male']
# Out:
#      PassengerId  Survived  class                            Name   Sex   Age  \
# 0              1         0      3         Braund, Mr. Owen Harris  male  22.0
# 4              5         0      3        Allen, Mr. William Henry  male  35.0
# 5              6         0      3                Moran, Mr. James  male   NaN
# 6              7         0      1         McCarthy, Mr. Timothy J  male  54.0
# 7              8         0      3  Palsson, Master. Gosta Leonard  male   2.0
# ..           ...       ...    ...                             ...   ...   ...
# 883          884         0      2   Banfield, Mr. Frederick James  male  28.0
# 884          885         0      3          Sutehall, Mr. Henry Jr  male  25.0
# 886          887         0      2           Montvila, Rev. Juozas  male  27.0
# 889          890         1      1           Behr, Mr. Karl Howell  male  26.0
# 890          891         0      3             Dooley, Mr. Patrick  male  32.0
#
# ...

# %%
#count the number of male and female passengers
df['Sex'].value_counts()
# Out:
# Sex
# male      577
# female    314
# Name: count, dtype: int64

# %%
#count the number of classes
df['class'].value_counts()
# Out:
# class
# 3    491
# 1    216
# 2    184
# Name: count, dtype: int64

# %%
#find the percentage of male and female
print(df['Sex'].value_counts(normalize=True))
percentage = df['Sex'].value_counts(normalize = True)
print(percentage*100)
val1 = percentage[0]
val2 = percentage[1]
print(val1)
print(val2)
# Out:
# Sex
# male      0.647587
# female    0.352413
# Name: proportion, dtype: float64
# Sex
# male      64.758698
# female    35.241302
# Name: proportion, dtype: float64
# 0.6475869809203143
# 0.35241301907968575

# %%
#accessing the columns directly + filtering(multiple condition)
#get the count of survived passsengers  whose gender is female
#series and series cannoted by analyzes by and operator but can be used bitwise and(&)
df[(df['Survived'] == 1) & (df['Sex'] == 'female') & (df['Age'] < 18)]
# Out:
#      PassengerId  Survived  class  \
# 9             10         1      2
# 10            11         1      3
# 22            23         1      3
# 39            40         1      3
# 43            44         1      2
# 58            59         1      2
# 68            69         1      3
# 84            85         1      2
# 156          157         1      3
# 172          173         1      3
# 184          185         1      3
# 208          209         1      3
# 233          234         1      3
# 237          238         1      2
# 307          308         1      1
# 329          330         1      1
# 381          382         1      3
# 389          390         1      2
# 435          436         1      1
# 446          447         1      2
# 448          449         1      3
# 469          470         1      3
# 479          480         1      3
# 504          505         1      1
# 530          531         1      2
# 535          536         1      2
# ...

# %%
#Accesing the columns direactly  + filtering(multiple condition) and accessing desired columns
print("for single column accessing \n",df[(df['Survived'] == 1) & (df['Sex'] == 'female') & (df['Age'] < 18)]['class'])
print("\n")
print("for accessing the multiple columns \n",df[(df['Survived'] == 1) & (df['Sex'] == 'female') & (df['Age'] < 18)][['class','Name']])
# Out:
# for single column accessing
#  9      2
# 10     3
# 22     3
# 39     3
# 43     2
# 58     2
# 68     3
# 84     2
# 156    3
# 172    3
# 184    3
# 208    3
# 233    3
# 237    2
# 307    1
# 329    1
# 381    3
# 389    2
# 435    1
# 446    2
# 448    3
# 469    3
# 479    3
# 504    1
# 530    2
# 535    2
# 618    2
# 644    3
# 689    1
# 691    3
# 720    2
# 750    2
# 777    3
# 780    3
# 781    1
# 830    3
# 853    1
# 875    3
# Name: class, dtype: int64
#
#
# for accessing the multiple columns
#       class                                               Name
# 9        2                Nasser, Mrs. Nicholas (Adele Achem)
# 10       3                    Sandstrom, Miss. Marguerite Rut
# 22       3                        McGowan, Miss. Anna "Annie"
# 39       3                        Nicola-Yarred, Miss. Jamila
# 43       2           Laroche, Miss. Simonne Marie Anne Andree
# 58       2                       West, Miss. Constance Mirium
# ...

# %%
#access all the males who are less than 18 and their embarked should be in c
df[(df['Age'] < 18) & (df['Embarked'] == 'C') & (df['Sex'] == 'male')][['Sex','Age','Embarked']]
# Out:
#       Sex    Age Embarked
# 125  male  12.00        C
# 352  male  15.00        C
# 532  male  17.00        C
# 550  male  17.00        C
# 731  male  11.00        C
# 803  male   0.42        C
# 827  male   1.00        C

# %%
#access the column embarked embarked should be either c or s and count the value of the both
df['Embarked'].isin(['S','C']).value_counts() #using isin function
# Out:
# Embarked
# True     812
# False     79
# Name: count, dtype: int64

# %%
#Accessing the columns directly + filtering(multiple condition w isin)
#Access the survived and the class should be either 1 or 2 then the age should be greater than 18
print("without using isin \n",df[((df['class'] == 1) | (df['class'] == 2)) & (df['Survived'] == 1) & (df['Age'] > 18)][['Survived','class','Age']])
print("\n")
print("by using isin \n",df[(df['class'].isin([1,2])) & (df['Survived'] == 1) & (df['Age'] > 18)][['Survived','class','Age']])
# Out:
# without using isin
#       Survived  class   Age
# 1           1      1  38.0
# 3           1      1  35.0
# 11          1      1  58.0
# 15          1      2  55.0
# 21          1      2  34.0
# ..        ...    ...   ...
# 874         1      2  28.0
# 879         1      1  56.0
# 880         1      2  25.0
# 887         1      1  19.0
# 889         1      1  26.0
#
# [168 rows x 3 columns]
#
#
# by using isin
#       Survived  class   Age
# 1           1      1  38.0
# 3           1      1  35.0
# 11          1      1  58.0
# 15          1      2  55.0
# 21          1      2  34.0
# ..        ...    ...   ...
# 874         1      2  28.0
# 879         1      1  56.0
# 880         1      2  25.0
# 887         1      1  19.0
# 889         1      1  26.0
#
# [168 rows x 3 columns]

# %%
#Access the survived and the class should be either 1 or 2 then the age with only first 10 rows
print("by using isin \n",df[(df['class'].isin([1,2])) & (df['Survived'] == 1) & (df['Age'] > 18)][['Survived','class','Age']].head(10))
#Access the survived and the class should be either 1 or 2 then the age with exclude last 50 rows
print("by using isin exclude last 50 rows \n",df[(df['class'].isin([1,2])) & (df['Survived'] == 1) & (df['Age'] > 18)][['Survived','class','Age']].head(-50))
#Access the survived and the class should be either 1 or 2 then the age with exclude first 50 rows
print("by using isin exclude first 50 rows \n",df[(df['class'].isin([1,2])) & (df['Survived'] == 1) & (df['Age'] > 18)][['Survived','class','Age']].tail(-50))
# Out:
# by using isin
#      Survived  class   Age
# 1          1      1  38.0
# 3          1      1  35.0
# 11         1      1  58.0
# 15         1      2  55.0
# 21         1      2  34.0
# 23         1      1  28.0
# 52         1      1  49.0
# 53         1      2  29.0
# 56         1      2  21.0
# 61         1      1  38.0
# by using isin exclude last 50 rows
#       Survived  class   Age
# 1           1      1  38.0
# 3           1      1  35.0
# 11          1      1  58.0
# 15          1      2  55.0
# 21          1      2  34.0
# ..        ...    ...   ...
# 608         1      2  22.0
# 609         1      1  40.0
# 615         1      2  24.0
# 621         1      1  42.0
# 627         1      1  21.0
#
# [118 rows x 3 columns]
# by using isin exclude first 50 rows
#       Survived  class   Age
# 325         1      1  36.0
# 327         1      2  36.0
# 337         1      1  41.0
# 341         1      1  24.0
# 345         1      2  24.0
# ..        ...    ...   ...
# ...

# %%
#count the no of passengers who have survived and they must belong from either S or C embarked and their fare should be less than 100
df[(df['Embarked'].isin(['S','C'])) & (df['Survived'] == 1) & (df['Fare'] < 100)][['Survived','Embarked','Fare']].count()
# Out:
# Survived    271
# Embarked    271
# Fare        271
# dtype: int64

# %%
#Accessing the columns directly + filtering + sorting
#count the no of passengers who have survived and they must belong from either S or C embarked and their fare should be less than 100
df[(df['Embarked'].isin(['S','C'])) & (df['Survived'] == 1) & (df['Fare'] < 100)][['Survived','Embarked','Fare']].sort_values(by = 'Fare')
# Out:
#      Survived Embarked     Fare
# 271         1        S   0.0000
# 804         1        S   6.9750
# 127         1        S   7.1417
# 553         1        C   7.2250
# 875         1        C   7.2250
# ..        ...      ...      ...
# 486         1        S  90.0000
# 291         1        C  91.0792
# 484         1        C  91.0792
# 520         1        S  93.5000
# 820         1        S  93.5000
#
# [271 rows x 3 columns]

# %%
#count the no of passengers who have survived and they must belong from either S or C embarked and their fare should be less than 100 and get top 20 rows
df[(df['Embarked'].isin(['S','C'])) & (df['Survived'] == 1) & (df['Fare'] < 100)][['Survived','Embarked','Fare']].sort_values(by = 'Fare').head(20)
# Out:
#      Survived Embarked    Fare
# 271         1        S  0.0000
# 804         1        S  6.9750
# 127         1        S  7.1417
# 553         1        C  7.2250
# 875         1        C  7.2250
# 19          1        C  7.2250
# 762         1        C  7.2292
# 780         1        C  7.2292
# 36          1        C  7.2292
# 367         1        C  7.2292
# 376         1        S  7.2500
# 786         1        S  7.4958
# 649         1        S  7.5500
# 106         1        S  7.6500
# 141         1        S  7.7500
# 107         1        S  7.7750
# 554         1        S  7.7750
# 267         1        S  7.7750
# 146         1        S  7.7958
# 391         1        S  7.7958

# %%
#sorting in descending order
df[(df['Embarked'].isin(['S','C'])) & (df['Survived'] == 1) & (df['Fare'] < 100)][['Survived','Embarked','Fare']].sort_values(by = 'Fare',ascending = False)
# Out:
#      Survived Embarked     Fare
# 520         1        S  93.5000
# 820         1        S  93.5000
# 291         1        C  91.0792
# 484         1        C  91.0792
# 224         1        S  90.0000
# ..        ...      ...      ...
# 875         1        C   7.2250
# 19          1        C   7.2250
# 127         1        S   7.1417
# 804         1        S   6.9750
# 271         1        S   0.0000
#
# [271 rows x 3 columns]

# %%
#sorting in descending  and excluding last 50 rows
df[(df['Embarked'].isin(['S','C'])) & (df['Survived'] == 1) & (df['Fare'] < 100)][['Survived','Embarked','Fare']].sort_values(by = 'Fare',ascending = False).head(-50)
# Out:
#      Survived Embarked     Fare
# 520         1        S  93.5000
# 820         1        S  93.5000
# 291         1        C  91.0792
# 484         1        C  91.0792
# 224         1        S  90.0000
# ..        ...      ...      ...
# 717         1        S  10.5000
# 570         1        S  10.5000
# 84          1        S  10.5000
# 226         1        S  10.5000
# 66          1        S  10.5000
#
# [221 rows x 3 columns]

# %%
#passengers who are dead their sex has to be female and age has to be > 18 and sort the age in a descending order
df[(df['Survived']==0) & (df['Age'] > 18) & (df['Sex'] == 'female')].sort_values(by = 'Age',ascending=False)
# Out:
#      PassengerId  Survived  class  \
# 772          773         0      2
# 177          178         0      1
# 736          737         0      3
# 132          133         0      3
# 362          363         0      3
# 276          277         0      3
# 167          168         0      3
# 854          855         0      2
# 678          679         0      3
# 638          639         0      3
# 254          255         0      3
# 40            41         0      3
# 610          611         0      3
# 885          886         0      3
# 357          358         0      2
# 503          504         0      3
# 657          658         0      3
# 18            19         0      3
# 396          397         0      3
# 767          768         0      3
# 534          535         0      3
# 799          800         0      3
# 251          252         0      3
# 567          568         0      3
# 423          424         0      3
# 100          101         0      3
# ...

# %%
#sorting the values in series
print("data type ",type(df['Age']))
#sorting by series
print("sort by age",df['Age'].sort_values(axis=0))
# Out:
# data type  <class 'pandas.core.series.Series'>
# sort by age 803    0.42
# 755    0.67
# 644    0.75
# 469    0.75
# 78     0.83
#        ...
# 859     NaN
# 863     NaN
# 868     NaN
# 878     NaN
# 888     NaN
# Name: Age, Length: 891, dtype: float64

# %%
#loc and iloc function (Index lock function) here location is loc
#syntax:  df.loc[strt_index:stop_index(rows):stepsize, column_name]
#syntax:  df.iloc[strt_index:stop_index(rows):stepsize,strt_index:stop_index(columns):stepsize]
df.loc[10:20:2]  #to access a particular location data
# Out:
#     PassengerId  Survived  class  \
# 10           11         1      3
# 12           13         0      3
# 14           15         0      3
# 16           17         0      3
# 18           19         0      3
# 20           21         0      2
#
#                                                  Name     Sex   Age  SibSp  \
# 10                    Sandstrom, Miss. Marguerite Rut  female   4.0      1
# 12                     Saundercock, Mr. William Henry    male  20.0      0
# 14               Vestrom, Miss. Hulda Amanda Adolfina  female  14.0      0
# 16                               Rice, Master. Eugene    male   2.0      4
# 18  Vander Planke, Mrs. Julius (Emelia Maria Vande...  female  31.0      1
# 20                               Fynney, Mr. Joseph J    male  35.0      0
#
#     Parch     Ticket     Fare Cabin Embarked
# 10      1    PP 9549  16.7000    G6        S
# 12      0  A/5. 2151   8.0500   NaN        S
# 14      0     350406   7.8542   NaN        S
# ...

# %%
#accessing all rows from 50 to 100 and specified columns
df.loc[50:100,['Name','Age','Fare']]
# Out:
#                                                   Name    Age      Fare
# 50                          Panula, Master. Juha Niilo   7.00   39.6875
# 51                        Nosworthy, Mr. Richard Cater  21.00    7.8000
# 52            Harper, Mrs. Henry Sleeper (Myna Haxtun)  49.00   76.7292
# 53   Faunthorpe, Mrs. Lizzie (Elizabeth Anne Wilkin...  29.00   26.0000
# 54                      Ostby, Mr. Engelhart Cornelius  65.00   61.9792
# 55                                   Woolner, Mr. Hugh    NaN   35.5000
# 56                                   Rugg, Miss. Emily  21.00   10.5000
# 57                                 Novel, Mr. Mansouer  28.50    7.2292
# 58                        West, Miss. Constance Mirium   5.00   27.7500
# 59                  Goodwin, Master. William Frederick  11.00   46.9000
# 60                               Sirayanian, Mr. Orsen  22.00    7.2292
# 61                                 Icard, Miss. Amelie  38.00   80.0000
# ...

# %%
#access the rows from 50 to 100 and use iloc function
df.iloc[50:100, [3,5,8]]
# Out:
#                                                  Name    Age           Ticket
# 50                         Panula, Master. Juha Niilo   7.00          3101295
# 51                       Nosworthy, Mr. Richard Cater  21.00       A/4. 39886
# 52           Harper, Mrs. Henry Sleeper (Myna Haxtun)  49.00         PC 17572
# 53  Faunthorpe, Mrs. Lizzie (Elizabeth Anne Wilkin...  29.00             2926
# 54                     Ostby, Mr. Engelhart Cornelius  65.00           113509
# 55                                  Woolner, Mr. Hugh    NaN            19947
# 56                                  Rugg, Miss. Emily  21.00       C.A. 31026
# 57                                Novel, Mr. Mansouer  28.50             2697
# 58                       West, Miss. Constance Mirium   5.00       C.A. 34651
# 59                 Goodwin, Master. William Frederick  11.00          CA 2144
# 60                              Sirayanian, Mr. Orsen  22.00             2669
# ...

# %%
#accessing all rows and columns indexing from 4 to 8
df.iloc[50:100,4:9]
# Out:
#        Sex    Age  SibSp  Parch           Ticket
# 50    male   7.00      4      1          3101295
# 51    male  21.00      0      0       A/4. 39886
# 52  female  49.00      1      0         PC 17572
# 53  female  29.00      1      0             2926
# 54    male  65.00      0      1           113509
# 55    male    NaN      0      0            19947
# 56  female  21.00      0      0       C.A. 31026
# 57    male  28.50      0      0             2697
# 58  female   5.00      1      2       C.A. 34651
# 59    male  11.00      5      2          CA 2144
# 60    male  22.00      0      0             2669
# 61  female  38.00      0      0           113572
# 62    male  45.00      1      0            36973
# 63    male   4.00      3      2           347088
# 64    male    NaN      0      0         PC 17605
# 65    male    NaN      1      1             2661
# 66  female  29.00      0      0       C.A. 29395
# 67    male  19.00      0      0        S.P. 3464
# ...

# %%
df.loc[250:300,['PassengerId','class','Age']]
# Out:
#      PassengerId  class   Age
# 250          251      3   NaN
# 251          252      3  29.0
# 252          253      1  62.0
# 253          254      3  30.0
# 254          255      3  41.0
# 255          256      3  29.0
# 256          257      1   NaN
# 257          258      1  30.0
# 258          259      1  35.0
# 259          260      2  50.0
# 260          261      3   NaN
# 261          262      3   3.0
# 262          263      1  52.0
# 263          264      1  40.0
# 264          265      3   NaN
# 265          266      2  36.0
# 266          267      3  16.0
# 267          268      3  25.0
# 268          269      1  58.0
# 269          270      1  35.0
# 270          271      1   NaN
# 271          272      3  25.0
# 272          273      2  41.0
# 273          274      1  37.0
# 274          275      3   NaN
# 275          276      1  63.0
# 276          277      3  45.0
# 277          278      2   NaN
# 278          279      3   7.0
# 279          280      3  35.0
# ...

# %%
#by using iloc access all the rows from 500 to 525 and columns are survived name and age
df.iloc[500:525,1:6:2]
# Out:
#      Survived                                               Name   Age
# 500         0                                   Calic, Mr. Petar  17.0
# 501         0                                Canavan, Miss. Mary  21.0
# 502         0                     O'Sullivan, Miss. Bridget Mary   NaN
# 503         0                     Laitinen, Miss. Kristina Sofia  37.0
# 504         1                              Maioni, Miss. Roberta  16.0
# 505         0         Penasco y Castellana, Mr. Victor de Satode  18.0
# 506         1      Quick, Mrs. Frederick Charles (Jane Richards)  33.0
# 507         1      Bradley, Mr. George ("George Arthur Brayton")   NaN
# 508         0                           Olsen, Mr. Henry Margido  28.0
# 509         1                                     Lang, Mr. Fang  26.0
# 510         1                           Daly, Mr. Eugene Patrick  29.0
# 511         0                                  Webber, Mr. James   NaN
# ...

# %%
#adding a new column and assigning values to it
df.dropna(inplace = True)
df['Discounted_price'] = df['Fare'] * 0.10 #Discounted_price column is added
df['Fare_after_discount'] = df['Fare'] - df['Discounted_price']
df
# Out:
#      PassengerId  Survived  class  \
# 1              2         1      1
# 3              4         1      1
# 6              7         0      1
# 10            11         1      3
# 11            12         1      1
# ..           ...       ...    ...
# 871          872         1      1
# 872          873         0      1
# 879          880         1      1
# 887          888         1      1
# 889          890         1      1
#
#                                                   Name     Sex   Age  SibSp  \
# 1    Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 3         Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 6                              McCarthy, Mr. Timothy J    male  54.0      0
# 10                     Sandstrom, Miss. Marguerite Rut  female   4.0      1
# 11                            Bonnell, Miss. Elizabeth  female  58.0      0
# ..                                                 ...     ...   ...    ...
# ...

# %%
#dropping a particular column
df.drop('Fare_after_discount',axis = 1,inplace = True)
df
# Out:
#      PassengerId  Survived  class  \
# 1              2         1      1
# 3              4         1      1
# 6              7         0      1
# 10            11         1      3
# 11            12         1      1
# ..           ...       ...    ...
# 871          872         1      1
# 872          873         0      1
# 879          880         1      1
# 887          888         1      1
# 889          890         1      1
#
#                                                   Name     Sex   Age  SibSp  \
# 1    Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 3         Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 6                              McCarthy, Mr. Timothy J    male  54.0      0
# 10                     Sandstrom, Miss. Marguerite Rut  female   4.0      1
# 11                            Bonnell, Miss. Elizabeth  female  58.0      0
# ..                                                 ...     ...   ...    ...
# ...

# %%
#Group by function and this function is used to group data in collections
print("to access all columns count \n",df.groupby(by = 'Sex').count())
print("to access the specified columns \n",df.groupby(by = 'Sex')['class'].count())
# Out:
# to access all columns count
#          PassengerId  Survived  class  Name  Age  SibSp  Parch  Ticket  Fare  \
# Sex
# female           88        88     88    88   88     88     88      88    88
# male             95        95     95    95   95     95     95      95    95
#
#         Cabin  Embarked  Discounted_price
# Sex
# female     88        88                88
# male       95        95                95
# to access the specified columns
#  Sex
# female    88
# male      95
# Name: class, dtype: int64

# %%
#using aggregation function
df.groupby(by = 'Embarked')['Fare'].agg(['max','min','mean'])
# Out:
#                max     min        mean
# Embarked
# C         512.3292  12.875  103.342503
# Q          90.0000  90.000   90.000000
# S         263.0000   0.000   64.669216

# %%
#grouping by multiple columns
df.groupby(by = ['class','Sex']).count()
# Out:
#               PassengerId  Survived  Name  Age  SibSp  Parch  Ticket  Fare  \
# class Sex
# 1     female           74        74    74   74     74     74      74    74
#       male             84        84    84   84     84     84      84    84
# 2     female            9         9     9    9      9      9       9     9
#       male              6         6     6    6      6      6       6     6
# 3     female            5         5     5    5      5      5       5     5
#       male              5         5     5    5      5      5       5     5
#
#               Cabin  Embarked  Discounted_price
# class Sex
# 1     female     74        74                74
#       male       84        84                84
# 2     female      9         9                 9
#       male        6         6                 6
# 3     female      5         5                 5
#       male        5         5                 5

# %%
#find average of age, Fare as count and passenger id as count group by class and sex
df.groupby(by = ['class','Sex']).agg({'Age':'mean','Fare':'sum','PassengerId':'count'})
# Out:
#                     Age       Fare  PassengerId
# class Sex
# 1     female  34.094595  7631.4875           74
#       male    40.671667  6380.4626           84
# 2     female  29.611111   133.7917            9
#       male    18.750000   142.8750            6
# 3     female  17.200000    66.8000            5
#       male    24.800000    43.4750            5
